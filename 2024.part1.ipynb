# %% [markdown]
# ## 1.Setup Basic Parameters

# %%
import numpy as np

# Parameters
Tmax = 5
D = 6  # Number of locations
L = 1  # Number of locations connected to the outside world
n = np.array([0, 2000, 3000, 1200, 1500, 3200])  # Population at each location

# %% [markdown]
# ## 2. Create Connectivity Matrix W

# %%
def create_connectivity_matrix(D, L):
    W = np.zeros((D, D), dtype=int)
    
    # Populate W with random values and ensure symmetry
    for i in range(1, D):
        for j in range(i+1, D):
            W[i, j] = np.random.randint(0, 100)  # Adjust range as needed
            W[j, i] = W[i, j]

    # Set the connections from the outside world
    for i in range(1, L+1):
        W[0, i] = W[i, 0] = np.random.randint(1, 100)  # Ensure these are non-zero

    # Zero out the diagonal
    np.fill_diagonal(W, 0)
    return W

W = create_connectivity_matrix(D, L)

# %%
import pandas as pd

W = create_connectivity_matrix(D, L)

# Convert the matrix to a DataFrame for better visualization
W_df = pd.DataFrame(W, columns=[f"Location {i+1}" for i in range(D)], index=[f"Location {i+1}" for i in range(D)])
W_df
# Out:
#             Location 1  Location 2  Location 3  Location 4  Location 5  \
# Location 1           0          25           0           0           0
# Location 2          25           0           9          46          40
# Location 3           0           9           0          72          47
# Location 4           0          46          72           0          55
# Location 5           0          40          47          55           0
# Location 6           0          26          38           2          12
#
#             Location 6
# Location 1           0
# Location 2          26
# Location 3          38
# Location 4           2
# Location 5          12
# Location 6           0

# %% [markdown]
# ## 3.Initialize State Vectors

# %%
# Initialize state vectors
x = np.zeros((D, 4), dtype=float)  # Use float type for the state vectors

for i in range(D):
    if n[i] == 0:
        x[i] = np.zeros(4)  # Explicitly set to zero for locations with zero population
    else:
        x[i] = np.random.randint(0, 100, size=4)
        x[i] = x[i] / x[i].sum()  # Normalize
        x[i] = x[i] * n[i]  # Scale by population
        x[i] = np.round(x[i]).astype(int)  # Round to integer

# %%
# Convert the state vectors to a DataFrame for better visualization
state_vectors_df = pd.DataFrame(x, columns=['Susceptible', 'Exposed', 'Infected', 'Recovered'], 
                                index=[f"Location {i+1}" for i in range(D)])
state_vectors_df
# Out:
#             Susceptible  Exposed  Infected  Recovered
# Location 1          0.0      0.0       0.0        0.0
# Location 2        426.0    149.0     660.0      766.0
# Location 3        117.0   1150.0    1000.0      733.0
# Location 4         46.0    347.0     311.0      495.0
# Location 5        220.0    606.0     441.0      233.0
# Location 6       1342.0    718.0     937.0      203.0

# %% [markdown]
# ## 4. Implement the Migration Logic

# %%
def balanced_migration_step(W, x):
    D = W.shape[0]
    Delta_out = np.zeros_like(x, dtype=float)  # Use float type
    Delta_in = np.zeros_like(x, dtype=float)   # Use float type

    # Calculating how many individuals will leave each location
    for i in range(D):
        for j in range(D):
            if i != j and W[i, j] > 0:
                for cat in range(4):
                    proportion = x[i, cat] / x[i].sum() if x[i].sum() > 0 else 0
                    Delta_out[i, cat] += W[i, j] * proportion

    # Ensuring the total number of people leaving a location equals those arriving
    for i in range(D):
        for j in range(D):
            if i != j and W[i, j] > 0:
                Delta_in[j] += Delta_out[i] * W[i, j] / W[i].sum() if W[i].sum() > 0 else 0

    # Adjust the population in each location
    x_new = x - np.round(Delta_out).astype(int) + np.round(Delta_in).astype(int)

    return x_new

# %%
x_new = balanced_migration_step(W, x)

# %%
x_new
# Out:
# array([[   5.,    2.,    8.,   10.],
#        [ 414.,  177.,  646.,  739.],
#        [ 139., 1135.,  992.,  735.],
#        [  61.,  350.,  322.,  467.],
#        [ 214.,  584.,  443.,  259.],
#        [1318.,  722.,  939.,  220.]])

# %% [markdown]
# ## 5. Implement Infection Dynamics

# %%
def infection_step(x):
    # Placeholder function for infection dynamics
    # Modify this function based on the specific infection model
    # For demonstration, we'll just pass the state without changes
    return x

# %%
x
# Out:
# array([[   0.,    0.,    0.,    0.],
#        [ 426.,  149.,  660.,  766.],
#        [ 117., 1150., 1000.,  733.],
#        [  46.,  347.,  311.,  495.],
#        [ 220.,  606.,  441.,  233.],
#        [1342.,  718.,  937.,  203.]])

# %% [markdown]
# ## 6. Run the Simulation

# %%
# Initialize history array to store state of each location on each day
history = np.zeros((Tmax, D, 4), dtype=int)

# Run the simulation
for t in range(Tmax):
    # Migration step
    x = balanced_migration_step(W, x)

    # Infection step
    x = infection_step(x)

    # Record the state for the day
    history[t] = x

# Convert history to a DataFrame for better visualization (optional)
# This step creates a DataFrame showing the state of each location on each day
history_df = pd.DataFrame(history.reshape(Tmax * D, 4), 
                          columns=['Susceptible', 'Exposed', 'Infected', 'Recovered'],
                          index=[f"Day {t // D + 1}, Location {t % D + 1}" for t in range(Tmax * D)])

# %%
history_df
# Out:
#                    Susceptible  Exposed  Infected  Recovered
# Day 1, Location 1            5        2         8         10
# Day 1, Location 2          414      177       646        739
# Day 1, Location 3          139     1135       992        735
# Day 1, Location 4           61      350       322        467
# Day 1, Location 5          214      584       443        259
# Day 1, Location 6         1318      722       939        220
# Day 2, Location 1            5        2         8          9
# Day 2, Location 2          407      204       641        723
# Day 2, Location 3          159     1121       984        736
# Day 2, Location 4           74      352       331        443
# Day 2, Location 5          210      564       445        281
# Day 2, Location 6         1295      726       941        237
# Day 3, Location 1            5        3         8          9
# Day 3, Location 2          402      229       637        708
# Day 3, Location 3          178     1107       978        736
# Day 3, Location 4           85      354       338        423
# Day 3, Location 5          207      547       446        299
# Day 3, Location 6         1272      730       943        253
# Day 4, Location 1            5        3         8          9
# Day 4, Location 2          397      252       633        693
# Day 4, Location 3          197     1094       972        736
# Day 4, Location 4           95      354       344        406
# Day 4, Location 5          206      532       447        314
# Day 4, Location 6         1250      734       945        269
# Day 5, Location 1            5        3         8          9
# Day 5, Location 2          393      273       630        679
# Day 5, Location 3          215     1081       967        736
# Day 5, Location 4          103      354       349        392
# Day 5, Location 5          205      518       448        327
# Day 5, Location 6         1230      738       947        284

# %%
x
# Out:
# array([[   5.,    3.,    8.,    9.],
#        [ 393.,  273.,  630.,  679.],
#        [ 215., 1081.,  967.,  736.],
#        [ 103.,  354.,  349.,  392.],
#        [ 205.,  518.,  448.,  327.],
#        [1230.,  738.,  947.,  284.]])

# %%
history
# Out:
# array([[[   5,    2,    8,   10],
#         [ 414,  177,  646,  739],
#         [ 139, 1135,  992,  735],
#         [  61,  350,  322,  467],
#         [ 214,  584,  443,  259],
#         [1318,  722,  939,  220]],
#
#        [[   5,    2,    8,    9],
#         [ 407,  204,  641,  723],
#         [ 159, 1121,  984,  736],
#         [  74,  352,  331,  443],
#         [ 210,  564,  445,  281],
#         [1295,  726,  941,  237]],
#
#        [[   5,    3,    8,    9],
#         [ 402,  229,  637,  708],
#         [ 178, 1107,  978,  736],
#         [  85,  354,  338,  423],
#         [ 207,  547,  446,  299],
#         [1272,  730,  943,  253]],
#
#        [[   5,    3,    8,    9],
#         [ 397,  252,  633,  693],
#         [ 197, 1094,  972,  736],
#         [  95,  354,  344,  406],
#         [ 206,  532,  447,  314],
#         [1250,  734,  945,  269]],
#
#        [[   5,    3,    8,    9],
#         [ 393,  273,  630,  679],
#         [ 215, 1081,  967,  736],
#         [ 103,  354,  349,  392],
#         [ 205,  518,  448,  327],
#         [1230,  738,  947,  284]]])

# %% [markdown]
# ## 7. Plot

# %% [raw]
# import matplotlib.pyplot as plt
#
# # Plotting the simulation results for all locations and compartments over time
# compartment_labels = ['Susceptible', 'Exposed', 'Infected', 'Recovered']
# colors = ['blue', 'orange', 'green', 'red']
#
# # Setting up the plot
# plt.figure(figsize=(15, 8))
#
# # Plotting each compartment for all locations
# for j in range(4):
#     compartment_data = history[:, :, j].sum(axis=1)  # Summing across all locations for each compartment
#     plt.plot(compartment_data, label=compartment_labels[j], color=colors[j])
#
# plt.title("Total Population Dynamics Across All Locations Over Time")
# plt.xlabel("Time (days)")
# plt.ylabel("Total Population")
# plt.legend()
# plt.grid(True)
# plt.show()

# %% [raw]
# # Creating DataFrame to show the results
# daily_matrices = []
# for day in range(Tmax):
#     day_df = pd.DataFrame(history[day], columns=['Susceptible', 'Exposed', 'Infected', 'Recovered'],
#                           index=[f"Location {i+1}" for i in range(D)])
#     day_df['Day'] = day + 1
#     daily_matrices.append(day_df)
#
# # Concatenate all daily DataFrames for visualization
# all_days_df = pd.concat(daily_matrices)
# all_days_df

# %%
import matplotlib.pyplot as plt

# Plotting the results for each location through time
compartment_labels = ['Susceptible', 'Exposed', 'Infected', 'Recovered']

# Creating a separate plot for each location
for i in range(D):
    plt.figure(figsize=(12, 6))
    for j in range(4):
        # Extracting the specific compartment data for each location
        compartment_data = history[:, i, j]
        plt.plot(compartment_data, label=compartment_labels[j])

    plt.title(f"Location {i+1} Population Dynamics Over Time")
    plt.xlabel("Time (days)")
    plt.ylabel("Population")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Initialize the history array
history = np.zeros((Tmax, D, 4))

for t in range(Tmax):
    # Record the current state
    history[t] = x

    # Migration step
    Delta = migration_step(W, x)

    # Update the population after migration
    for i in range(D):
        x[i] -= Delta[i]
        for j in range(D):
            if i != j:
                x[j] += Delta[i]

    # Infection step (placeholder function)
    x = infection_step(x, Delta)

# %%
import matplotlib.pyplot as plt

# Labels for the compartments
compartment_labels = ['Susceptible', 'Exposed', 'Infected', 'Recovered']

# Plotting
for i in range(D):
    plt.figure(figsize=(10, 6))
    for j in range(4):
        plt.plot(history[:, i, j], label=compartment_labels[j])

    plt.title(f"Location {i+1} Population Dynamics Over Time")
    plt.xlabel("Time (days)")
    plt.ylabel("Population")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Convert history to a DataFrame for better visualization
history_df_list = []
for day in range(Tmax):
    day_df = pd.DataFrame(history[day], columns=['Susceptible', 'Exposed', 'Infected', 'Recovered'], 
                          index=[f"Location {i+1}" for i in range(D)])
    day_df['Day'] = day + 1
    history_df_list.append(day_df)

history_df = pd.concat(history_df_list)

# Moving the 'Day' column to the first position and rounding values without decimals
history_df = history_df[['Day', 'Susceptible', 'Exposed', 'Infected', 'Recovered']]
history_df = history_df.round(0).astype(int)

history_df
